# %%
# IMPORT OUR DEPENDENCIES:  

#To create our randomly-selected coordinates:
import random
import requests
import numpy as np


#To hold our data and create dataframes:
import pandas as pd


#Our API keys, and citipy (newly installed for project), to import the city weather-data.
from config import api_key
from citipy import citipy 


#And to plot our data:
import matplotlib.pyplot as plt
import matplotlib


#Last, for any formating of plots (they may be needed):
import seaborn

# %%
# GETTING A RANDOM SET OF COORDINATES TO USE FOR CALLING ON CITY WEATHER: 

# First we define the Latitude & Longitude Zones and use numpy to select 
#..coordinates at random, given the earth's ranges:


latitude_zone = np.arange(-90,90,15)
longitude_zone = np.arange(-180,180,15)

# %%
# DATAFRAME TO HOLD OUR COORDINATES:

# Create our list/Pandas DataFrame & calling it "cities" which will hold the coordinates to their city.


cities_df = pd.DataFrame()

cities_df["Latitude"] = ""
cities_df["Longitude"] = ""

# %%
# COORDINATE SELECTION!

# First, using a coordinate systen we will assign "X" for latitude, and "Y" for long.
# For both latitude "X" & longitude "Y", we randomly select 500 unique coordinates:
# For the random samples we collect, we will assign "lats" for X and "lons" for y.
# We then will create/append the lists, "lat_samples" and "lon_samples", to use in dataframes.

for x in latitude_zone:
    for y in longitude_zone:
        x_values = list(np.arange(x,x+15,0.01))
        y_values = list(np.arange(y,y+15,0.01))
        lats = random.sample(x_values,500)
        lons = random.sample(y_values,500)
        lat_samples = [(x+dec_lat) for dec_lat in lats]
        lon_samples = [y+dec_lon for dec_lon in lons]
        cities_df = cities_df.append(pd.DataFrame.from_dict({"Latitude":lat_samples,
                                       "Longitude":lon_samples}))

# We then place the coordinates into our "cities" dataframe that was created above.        
cities_df = cities_df.reset_index(drop=True)

# %%
# USING CITIPY MODULE TO TIE COORDINATES TO A CORRESPONDING/NEARBY CITY:

cities_df["Closest City name"] = ""
cities_df["Closest Country code"] = ""
for index,row in cities_df.iterrows():
    city = citipy.nearest_city(row["Latitude"],row["Longitude"])
    cities_df.set_value(index,"Closest City name",city.city_name)
    cities_df.set_value(index,"Closest Country code",city.country_code)
# Out:
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
# CLEANING THE DATAFRAME: ELIMINATE COORDINATE-SETS THAT DON'T YIELD NEARBY CITIES:


# First we create a new data frame that eliminates coordinates that aren't near any city:
# ..Calling it "clean_cities":
filtered_cities_df = cities_df.drop(['Latitude', 'Longitude'],axis=1)
filtered_cities_df

# Next we filter for any possible duplicates (cities that come up twice)
filtered_cities_df = filtered_cities_df.drop_duplicates()

# %%
# CREATING OUR SET OF CITIES WE WILL MAKE AN API CALL WITH

# Creation of our random sample set of cities from our "clean" data frame (above).
# Now we use a sample size of 500 in order to return their weather data.
# ** We will call this group of 500, "selected_cities".

selected_cities = filtered_cities_df.sample(500)

selected_cities = selected_cities.reset_index(drop=True)

# %%
# USING API CALLS TO GATHER WEATHER INFO ON OUR SELECTED CITIES:

# We use Openweathermap to make our API CALLS:
# Set up format for the calls:
base_url = "http://api.openweathermap.org/data/2.5/weather"

app_id = api_key

params = { "appid" :app_id,"units":"metric" }

# %%
# NOW enter the call data, url formatting, variables we want to collect &
# interate through for our "selected_cities" group:

def encrypt_key(input_url):
    return input_url[0:53]+"<YourKey>"+input_url[85:]

for index,row in selected_cities.iterrows():
    params["q"] =f'{row["Closest City name"]},{row["Closest Country code"]}'
    print(f"Retrieving weather information for {params['q']}")
    city_weather_resp = requests.get(base_url,params)
    print(encrypt_key(city_weather_resp.url))
    city_weather_resp  = city_weather_resp.json()
    selected_cities.set_value(index,"Latitude",city_weather_resp.get("coord",{}).get("lat"))
    selected_cities.set_value(index,"Longitude",city_weather_resp.get("coord",{}).get("lon"))
    selected_cities.set_value(index,"Temperature",city_weather_resp.get("main",{}).get("temp_max"))
    selected_cities.set_value(index,"Wind speed",city_weather_resp.get("wind",{}).get("speed"))
    selected_cities.set_value(index,"Humidity",city_weather_resp.get("main",{}).get("humidity"))
    selected_cities.set_value(index,"Cloudiness",city_weather_resp.get("clouds",{}).get("all"))
# Out:
# Retrieving weather information for daphne,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=daphne%2Cus
# Retrieving weather information for myrtle beach,us
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Adam Knapp\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=myrtle+beach%2Cus
# Retrieving weather information for sciacca,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sciacca%2Cit
# Retrieving weather information for sao joao batista,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sao+joao+batista%2Cbr
# Retrieving weather information for braco do norte,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=braco+do+norte%2Cbr
# Retrieving weather information for naze,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=naze%2Cjp
# Retrieving weather information for cajibio,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cajibio%2Cco
# Retrieving weather information for nakama,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nakama%2Cjp
# Retrieving weather information for tautira,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tautira%2Cpf
# Retrieving weather information for yaguacire,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=yaguacire%2Chn
# Retrieving weather information for nuoro,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nuoro%2Cit
# Retrieving weather information for himora,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=himora%2Cet
# Retrieving weather information for masakin,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=masakin%2Ctn
# Retrieving weather information for polis,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=polis%2Ccy
# Retrieving weather information for garh maharaja,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=garh+maharaja%2Cpk
# Retrieving weather information for papetoai,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=papetoai%2Cpf
# Retrieving weather information for gayeri,bf
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gayeri%2Cbf
# Retrieving weather information for maceio,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=maceio%2Cbr
# Retrieving weather information for romitan,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=romitan%2Cuz
# Retrieving weather information for prachin buri,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=prachin+buri%2Cth
# Retrieving weather information for thohoyandou,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=thohoyandou%2Cza
# Retrieving weather information for sa kaeo,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sa+kaeo%2Cth
# Retrieving weather information for hoima,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hoima%2Cug
# Retrieving weather information for erdemli,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=erdemli%2Ctr
# Retrieving weather information for carpinteria,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=carpinteria%2Cus
# Retrieving weather information for koror,pw
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=koror%2Cpw
# Retrieving weather information for san andres,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+andres%2Cco
# Retrieving weather information for anderson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=anderson%2Cus
# Retrieving weather information for zhob,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zhob%2Cpk
# Retrieving weather information for mayya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mayya%2Cru
# Retrieving weather information for gumushane,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gumushane%2Ctr
# Retrieving weather information for jiaonan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jiaonan%2Ccn
# Retrieving weather information for hendersonville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hendersonville%2Cus
# Retrieving weather information for macomer,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=macomer%2Cit
# Retrieving weather information for guacimo,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=guacimo%2Ccr
# Retrieving weather information for ituiutaba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ituiutaba%2Cbr
# Retrieving weather information for itajuba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=itajuba%2Cbr
# Retrieving weather information for san cristobal,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+cristobal%2Cec
# Retrieving weather information for yabelo,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=yabelo%2Cet
# Retrieving weather information for kabanjahe,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kabanjahe%2Cid
# Retrieving weather information for muskegon,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=muskegon%2Cus
# Retrieving weather information for paralimni,cy
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=paralimni%2Ccy
# Retrieving weather information for kudahuvadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kudahuvadhoo%2Cmv
# Retrieving weather information for birecik,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=birecik%2Ctr
# Retrieving weather information for capao bonito,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=capao+bonito%2Cbr
# Retrieving weather information for farkhor,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=farkhor%2Ctj
# Retrieving weather information for burica,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=burica%2Cpa
# Retrieving weather information for dire dawa,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dire+dawa%2Cet
# Retrieving weather information for totma,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=totma%2Cru
# Retrieving weather information for navirai,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=navirai%2Cbr
# Retrieving weather information for montijo,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=montijo%2Cpa
# Retrieving weather information for sananduva,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sananduva%2Cbr
# Retrieving weather information for duma,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=duma%2Csy
# Retrieving weather information for michigan city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=michigan+city%2Cus
# Retrieving weather information for huntsville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=huntsville%2Cus
# Retrieving weather information for muscle shoals,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=muscle+shoals%2Cus
# Retrieving weather information for turukhansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=turukhansk%2Cru
# Retrieving weather information for andra,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=andra%2Cru
# Retrieving weather information for altamont,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=altamont%2Cus
# Retrieving weather information for kahta,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kahta%2Ctr
# Retrieving weather information for mazagao,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mazagao%2Cbr
# Retrieving weather information for nashville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nashville%2Cus
# Retrieving weather information for sarangani,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sarangani%2Cph
# Retrieving weather information for kaffrine,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kaffrine%2Csn
# Retrieving weather information for hun,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hun%2Cly
# Retrieving weather information for dalvik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dalvik%2Cis
# Retrieving weather information for tripoli,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tripoli%2Cly
# Retrieving weather information for penapolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=penapolis%2Cbr
# Retrieving weather information for ketou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ketou%2Cbj
# Retrieving weather information for nanga eboko,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nanga+eboko%2Ccm
# Retrieving weather information for half moon bay,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=half+moon+bay%2Cus
# Retrieving weather information for orangeburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=orangeburg%2Cus
# Retrieving weather information for bon air,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bon+air%2Cus
# Retrieving weather information for filadelfia,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=filadelfia%2Cpy
# Retrieving weather information for cayhagan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cayhagan%2Cph
# Retrieving weather information for uyemskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=uyemskiy%2Cru
# Retrieving weather information for male,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=male%2Cmv
# Retrieving weather information for izumo,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=izumo%2Cjp
# Retrieving weather information for shagamu,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=shagamu%2Cng
# Retrieving weather information for riverton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=riverton%2Cus
# Retrieving weather information for westminster,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=westminster%2Cus
# Retrieving weather information for reconquista,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=reconquista%2Car
# Retrieving weather information for jubayl,lb
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jubayl%2Clb
# Retrieving weather information for blonduos,is
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=blonduos%2Cis
# Retrieving weather information for pangnirtung,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pangnirtung%2Cca
# Retrieving weather information for el cope,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=el+cope%2Cpa
# Retrieving weather information for millau,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=millau%2Cfr
# Retrieving weather information for tres pontas,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tres+pontas%2Cbr
# Retrieving weather information for muisne,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=muisne%2Cec
# Retrieving weather information for sanger,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sanger%2Cus
# Retrieving weather information for madarounfa,ne
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=madarounfa%2Cne
# Retrieving weather information for ileza,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ileza%2Cru
# Retrieving weather information for ingersoll,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ingersoll%2Cca
# Retrieving weather information for marysville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=marysville%2Cus
# Retrieving weather information for pechenga,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pechenga%2Cru
# Retrieving weather information for tieling,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tieling%2Ccn
# Retrieving weather information for ozark,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ozark%2Cus
# Retrieving weather information for agde,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=agde%2Cfr
# Retrieving weather information for nagato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nagato%2Cjp
# Retrieving weather information for bloomfield,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bloomfield%2Cus
# Retrieving weather information for nicoya,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nicoya%2Ccr
# Retrieving weather information for taraza,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=taraza%2Cco
# Retrieving weather information for ibaiti,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ibaiti%2Cbr
# Retrieving weather information for olean,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=olean%2Cus
# Retrieving weather information for carson city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=carson+city%2Cus
# Retrieving weather information for changtu,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=changtu%2Ccn
# Retrieving weather information for kapoeta,sd
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kapoeta%2Csd
# Retrieving weather information for arys,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=arys%2Ckz
# Retrieving weather information for nushki,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nushki%2Cpk
# Retrieving weather information for labytnangi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=labytnangi%2Cru
# Retrieving weather information for bourail,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bourail%2Cnc
# Retrieving weather information for uhlove,ua
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=uhlove%2Cua
# Retrieving weather information for albania,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=albania%2Cco
# Retrieving weather information for perbaungan,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=perbaungan%2Cid
# Retrieving weather information for corn island,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=corn+island%2Cni
# Retrieving weather information for ilinskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ilinskiy%2Cru
# Retrieving weather information for lang suan,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=lang+suan%2Cth
# Retrieving weather information for rogun,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rogun%2Ctj
# Retrieving weather information for hendek,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hendek%2Ctr
# Retrieving weather information for bordighera,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bordighera%2Cit
# Retrieving weather information for itapirapua,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=itapirapua%2Cbr
# Retrieving weather information for beringovskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=beringovskiy%2Cru
# Retrieving weather information for yuzhno-yeniseyskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=yuzhno-yeniseyskiy%2Cru
# Retrieving weather information for saint-maximin-la-sainte-baume,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saint-maximin-la-sainte-baume%2Cfr
# Retrieving weather information for mvuma,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mvuma%2Czw
# Retrieving weather information for cadillac,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cadillac%2Cus
# Retrieving weather information for bin qirdan,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bin+qirdan%2Ctn
# Retrieving weather information for rudbar,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rudbar%2Caf
# Retrieving weather information for chaman,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=chaman%2Cpk
# Retrieving weather information for ekuvukeni,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ekuvukeni%2Cza
# Retrieving weather information for olenegorsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=olenegorsk%2Cru
# Retrieving weather information for havelock,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=havelock%2Cus
# Retrieving weather information for gainesville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gainesville%2Cus
# Retrieving weather information for abinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=abinsk%2Cru
# Retrieving weather information for azacualpa,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=azacualpa%2Chn
# Retrieving weather information for racine,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=racine%2Cus
# Retrieving weather information for litoral del san juan,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=litoral+del+san+juan%2Cco
# Retrieving weather information for sinjar,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sinjar%2Ciq
# Retrieving weather information for salgar,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=salgar%2Cco
# Retrieving weather information for newport beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=newport+beach%2Cus
# Retrieving weather information for north bethesda,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=north+bethesda%2Cus
# Retrieving weather information for presidente epitacio,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=presidente+epitacio%2Cbr
# Retrieving weather information for traverse city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=traverse+city%2Cus
# Retrieving weather information for coolum beach,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=coolum+beach%2Cau
# Retrieving weather information for laurinburg,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=laurinburg%2Cus
# Retrieving weather information for severnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=severnyy%2Cru
# Retrieving weather information for shieli,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=shieli%2Ckz
# Retrieving weather information for saint simons,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saint+simons%2Cus
# Retrieving weather information for picayune,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=picayune%2Cus
# Retrieving weather information for zomin,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zomin%2Cuz
# Retrieving weather information for biloxi,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=biloxi%2Cus
# Retrieving weather information for vreed en hoop,gy
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=vreed+en+hoop%2Cgy
# Retrieving weather information for broni,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=broni%2Cit
# Retrieving weather information for ludvika,se
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ludvika%2Cse
# Retrieving weather information for kamennomostskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kamennomostskoye%2Cru
# Retrieving weather information for cacu,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cacu%2Cbr
# Retrieving weather information for shintomi,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=shintomi%2Cjp
# Retrieving weather information for bagn,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bagn%2Cno
# Retrieving weather information for divnomorskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=divnomorskoye%2Cru
# Retrieving weather information for nanpiao,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nanpiao%2Ccn
# Retrieving weather information for yaan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=yaan%2Ccn
# Retrieving weather information for dzhebariki-khaya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dzhebariki-khaya%2Cru
# Retrieving weather information for qiryat gat,il
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=qiryat+gat%2Cil
# Retrieving weather information for manjeshwar,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=manjeshwar%2Cin
# Retrieving weather information for polunochnoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=polunochnoye%2Cru
# Retrieving weather information for palimbang,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=palimbang%2Cph
# Retrieving weather information for igdir,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=igdir%2Ctr
# Retrieving weather information for glenwood springs,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=glenwood+springs%2Cus
# Retrieving weather information for duz,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=duz%2Ctn
# Retrieving weather information for simpsonville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=simpsonville%2Cus
# Retrieving weather information for notse,tg
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=notse%2Ctg
# Retrieving weather information for ammon,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ammon%2Cus
# Retrieving weather information for destin,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=destin%2Cus
# Retrieving weather information for kruisfontein,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kruisfontein%2Cza
# Retrieving weather information for kaabong,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kaabong%2Cug
# Retrieving weather information for nyagan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nyagan%2Cru
# Retrieving weather information for sao joao da barra,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sao+joao+da+barra%2Cbr
# Retrieving weather information for tumbagaan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tumbagaan%2Cph
# Retrieving weather information for laguna de perlas,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=laguna+de+perlas%2Cni
# Retrieving weather information for zaozerne,ua
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zaozerne%2Cua
# Retrieving weather information for chupa,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=chupa%2Cru
# Retrieving weather information for istmina,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=istmina%2Cco
# Retrieving weather information for alexander city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=alexander+city%2Cus
# Retrieving weather information for salinopolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=salinopolis%2Cbr
# Retrieving weather information for oyem,ga
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=oyem%2Cga
# Retrieving weather information for cubuk,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cubuk%2Ctr
# Retrieving weather information for tucson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tucson%2Cus
# Retrieving weather information for pontal do parana,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pontal+do+parana%2Cbr
# Retrieving weather information for basay,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=basay%2Cph
# Retrieving weather information for orange cove,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=orange+cove%2Cus
# Retrieving weather information for san pedro del parana,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+pedro+del+parana%2Cpy
# Retrieving weather information for ayni,tj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ayni%2Ctj
# Retrieving weather information for imbituba,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=imbituba%2Cbr
# Retrieving weather information for monrovia,lr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=monrovia%2Clr
# Retrieving weather information for nadvoitsy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nadvoitsy%2Cru
# Retrieving weather information for savalou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=savalou%2Cbj
# Retrieving weather information for lambari,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=lambari%2Cbr
# Retrieving weather information for nkowakowa,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nkowakowa%2Cza
# Retrieving weather information for sevierville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sevierville%2Cus
# Retrieving weather information for suoyarvi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=suoyarvi%2Cru
# Retrieving weather information for gerede,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gerede%2Ctr
# Retrieving weather information for dawlatabad,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dawlatabad%2Caf
# Retrieving weather information for mercedes,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mercedes%2Cph
# Retrieving weather information for carnarvon,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=carnarvon%2Cau
# Retrieving weather information for sheridan,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sheridan%2Cus
# Retrieving weather information for itabera,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=itabera%2Cbr
# Retrieving weather information for savona,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=savona%2Cit
# Retrieving weather information for silopi,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=silopi%2Ctr
# Retrieving weather information for trapani,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=trapani%2Cit
# Retrieving weather information for casas grandes,mx
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=casas+grandes%2Cmx
# Retrieving weather information for ahlat,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ahlat%2Ctr
# Retrieving weather information for realeza,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=realeza%2Cbr
# Retrieving weather information for mbour,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mbour%2Csn
# Retrieving weather information for gharb,mt
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gharb%2Cmt
# Retrieving weather information for tura,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tura%2Cru
# Retrieving weather information for barentu,er
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=barentu%2Cer
# Retrieving weather information for gulu,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gulu%2Cug
# Retrieving weather information for jamame,so
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jamame%2Cso
# Retrieving weather information for antequera,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=antequera%2Cpy
# Retrieving weather information for nhlangano,sz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nhlangano%2Csz
# Retrieving weather information for elmadag,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=elmadag%2Ctr
# Retrieving weather information for krabi,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=krabi%2Cth
# Retrieving weather information for palu,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=palu%2Cid
# Retrieving weather information for aasiaat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=aasiaat%2Cgl
# Retrieving weather information for auka,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=auka%2Chn
# Retrieving weather information for mumford,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mumford%2Cgh
# Retrieving weather information for sainte-maxime,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sainte-maxime%2Cfr
# Retrieving weather information for kirkenaer,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kirkenaer%2Cno
# Retrieving weather information for duki,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=duki%2Cpk
# Retrieving weather information for saint-martin-de-crau,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saint-martin-de-crau%2Cfr
# Retrieving weather information for dhidhdhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dhidhdhoo%2Cmv
# Retrieving weather information for pocone,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pocone%2Cbr
# Retrieving weather information for mahadday weyne,so
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mahadday+weyne%2Cso
# Retrieving weather information for grenada,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=grenada%2Cus
# Retrieving weather information for payakumbuh,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=payakumbuh%2Cid
# Retrieving weather information for kaseda,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kaseda%2Cjp
# Retrieving weather information for barentsburg,sj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=barentsburg%2Csj
# Retrieving weather information for bogo,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bogo%2Ccm
# Retrieving weather information for yingkou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=yingkou%2Ccn
# Retrieving weather information for umzimvubu,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=umzimvubu%2Cza
# Retrieving weather information for somerset,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=somerset%2Cus
# Retrieving weather information for paez,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=paez%2Cco
# Retrieving weather information for suez,eg
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=suez%2Ceg
# Retrieving weather information for asayita,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=asayita%2Cet
# Retrieving weather information for corning,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=corning%2Cus
# Retrieving weather information for anito,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=anito%2Cph
# Retrieving weather information for cookeville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cookeville%2Cus
# Retrieving weather information for abu kamal,sy
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=abu+kamal%2Csy
# Retrieving weather information for coshocton,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=coshocton%2Cus
# Retrieving weather information for washington,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=washington%2Cus
# Retrieving weather information for kampong chhnang,kh
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kampong+chhnang%2Ckh
# Retrieving weather information for loon,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=loon%2Cph
# Retrieving weather information for ponnani,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ponnani%2Cin
# Retrieving weather information for masvingo,zw
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=masvingo%2Czw
# Retrieving weather information for rena,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rena%2Cno
# Retrieving weather information for nilai,my
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nilai%2Cmy
# Retrieving weather information for rawah,iq
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rawah%2Ciq
# Retrieving weather information for machico,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=machico%2Cpt
# Retrieving weather information for grindavik,is
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=grindavik%2Cis
# Retrieving weather information for pangody,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pangody%2Cru
# Retrieving weather information for safaqis,tn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=safaqis%2Ctn
# Retrieving weather information for varzea grande,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=varzea+grande%2Cbr
# Retrieving weather information for zopilotepe,hn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zopilotepe%2Chn
# Retrieving weather information for bocas del toro,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bocas+del+toro%2Cpa
# Retrieving weather information for teodoro sampaio,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=teodoro+sampaio%2Cbr
# Retrieving weather information for dashitou,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dashitou%2Ccn
# Retrieving weather information for horta,pt
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=horta%2Cpt
# Retrieving weather information for fort erie,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=fort+erie%2Cca
# Retrieving weather information for kuantan,my
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kuantan%2Cmy
# Retrieving weather information for saryshagan,kz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saryshagan%2Ckz
# Retrieving weather information for rock springs,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rock+springs%2Cus
# Retrieving weather information for zelenoborskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zelenoborskiy%2Cru
# Retrieving weather information for konya,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=konya%2Ctr
# Retrieving weather information for san patricio,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+patricio%2Cpy
# Retrieving weather information for veraval,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=veraval%2Cin
# Retrieving weather information for borama,so
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=borama%2Cso
# Retrieving weather information for sungurlu,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sungurlu%2Ctr
# Retrieving weather information for porto-vecchio,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=porto-vecchio%2Cfr
# Retrieving weather information for anan,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=anan%2Cjp
# Retrieving weather information for niceville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=niceville%2Cus
# Retrieving weather information for conakry,gn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=conakry%2Cgn
# Retrieving weather information for puerto el triunfo,sv
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=puerto+el+triunfo%2Csv
# Retrieving weather information for kleive,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kleive%2Cno
# Retrieving weather information for surat thani,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=surat+thani%2Cth
# Retrieving weather information for portobelo,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=portobelo%2Cpa
# Retrieving weather information for belushya guba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=belushya+guba%2Cru
# Retrieving weather information for unye,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=unye%2Ctr
# Retrieving weather information for moerai,pf
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=moerai%2Cpf
# Retrieving weather information for port blair,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=port+blair%2Cin
# Retrieving weather information for nioaque,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nioaque%2Cbr
# Retrieving weather information for champaign,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=champaign%2Cus
# Retrieving weather information for simbahan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=simbahan%2Cph
# Retrieving weather information for zhuanghe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zhuanghe%2Ccn
# Retrieving weather information for alcantara,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=alcantara%2Cph
# Retrieving weather information for bireun,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bireun%2Cid
# Retrieving weather information for attawapiskat,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=attawapiskat%2Cca
# Retrieving weather information for lar gerd,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=lar+gerd%2Caf
# Retrieving weather information for ifo,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ifo%2Cng
# Retrieving weather information for starkville,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=starkville%2Cus
# Retrieving weather information for severomorsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=severomorsk%2Cru
# Retrieving weather information for dabat,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dabat%2Cet
# Retrieving weather information for malinao,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=malinao%2Cph
# Retrieving weather information for samoded,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=samoded%2Cru
# Retrieving weather information for bonga,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bonga%2Cet
# Retrieving weather information for lunel,fr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=lunel%2Cfr
# Retrieving weather information for hermanus,za
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hermanus%2Cza
# Retrieving weather information for abaete,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=abaete%2Cbr
# Retrieving weather information for rioblanco,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rioblanco%2Cco
# Retrieving weather information for gunjur,gm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gunjur%2Cgm
# Retrieving weather information for komsomolskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=komsomolskiy%2Cru
# Retrieving weather information for viseu,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=viseu%2Cbr
# Retrieving weather information for rungata,ki
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rungata%2Cki
# Retrieving weather information for phangnga,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=phangnga%2Cth
# Retrieving weather information for uwajima,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=uwajima%2Cjp
# Retrieving weather information for firminopolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=firminopolis%2Cbr
# Retrieving weather information for helong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=helong%2Ccn
# Retrieving weather information for vincennes,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=vincennes%2Cus
# Retrieving weather information for la ronge,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=la+ronge%2Cca
# Retrieving weather information for pensacola,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pensacola%2Cus
# Retrieving weather information for moreira sales,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=moreira+sales%2Cbr
# Retrieving weather information for saga,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saga%2Cjp
# Retrieving weather information for vityazevo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=vityazevo%2Cru
# Retrieving weather information for varca,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=varca%2Cin
# Retrieving weather information for pak phanang,th
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=pak+phanang%2Cth
# Retrieving weather information for sembabule,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sembabule%2Cug
# Retrieving weather information for oswego,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=oswego%2Cus
# Retrieving weather information for caimito,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=caimito%2Cco
# Retrieving weather information for san pawl il-bahar,mt
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+pawl+il-bahar%2Cmt
# Retrieving weather information for verdalsora,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=verdalsora%2Cno
# Retrieving weather information for sapao,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sapao%2Cph
# Retrieving weather information for port hope,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=port+hope%2Cca
# Retrieving weather information for deming,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=deming%2Cus
# Retrieving weather information for rupert,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rupert%2Cus
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tres+lagoas%2Cbr
# Retrieving weather information for zuwarah,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=zuwarah%2Cly
# Retrieving weather information for santa teresa,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=santa+teresa%2Cph
# Retrieving weather information for randallstown,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=randallstown%2Cus
# Retrieving weather information for groningen,sr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=groningen%2Csr
# Retrieving weather information for sabang,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sabang%2Cid
# Retrieving weather information for capitan bado,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=capitan+bado%2Cpy
# Retrieving weather information for saint-philippe,re
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saint-philippe%2Cre
# Retrieving weather information for santa fe,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=santa+fe%2Cus
# Retrieving weather information for adet,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=adet%2Cet
# Retrieving weather information for obera,ar
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=obera%2Car
# Retrieving weather information for nikolayevka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nikolayevka%2Cru
# Retrieving weather information for ranchpar,am
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ranchpar%2Cam
# Retrieving weather information for raudeberg,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=raudeberg%2Cno
# Retrieving weather information for uruzgan,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=uruzgan%2Caf
# Retrieving weather information for mount gambier,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mount+gambier%2Cau
# Retrieving weather information for tibagi,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tibagi%2Cbr
# Retrieving weather information for calafell,es
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=calafell%2Ces
# Retrieving weather information for hadejia,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hadejia%2Cng
# Retrieving weather information for sao pedro do sul,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sao+pedro+do+sul%2Cbr
# Retrieving weather information for cody,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cody%2Cus
# Retrieving weather information for dandong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=dandong%2Ccn
# Retrieving weather information for busselton,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=busselton%2Cau
# Retrieving weather information for mayskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mayskiy%2Cru
# Retrieving weather information for wencheng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=wencheng%2Ccn
# Retrieving weather information for irati,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=irati%2Cbr
# Retrieving weather information for ballina,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ballina%2Cau
# Retrieving weather information for porto torres,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=porto+torres%2Cit
# Retrieving weather information for hithadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=hithadhoo%2Cmv
# Retrieving weather information for cotonou,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cotonou%2Cbj
# Retrieving weather information for kota bahru,my
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kota+bahru%2Cmy
# Retrieving weather information for manado,id
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=manado%2Cid
# Retrieving weather information for jos,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jos%2Cng
# Retrieving weather information for muzaffarabad,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=muzaffarabad%2Cpk
# Retrieving weather information for lotofaga,ws
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=lotofaga%2Cws
# Retrieving weather information for aquidauana,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=aquidauana%2Cbr
# Retrieving weather information for worthington,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=worthington%2Cus
# Retrieving weather information for marquetalia,co
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=marquetalia%2Cco
# Retrieving weather information for awka,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=awka%2Cng
# Retrieving weather information for nadym,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nadym%2Cru
# Retrieving weather information for aksum,et
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=aksum%2Cet
# Retrieving weather information for batouri,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=batouri%2Ccm
# Retrieving weather information for santa fe,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=santa+fe%2Cpa
# Retrieving weather information for ziarat,pk
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ziarat%2Cpk
# Retrieving weather information for bozova,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bozova%2Ctr
# Retrieving weather information for calvia,es
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=calvia%2Ces
# Retrieving weather information for mbalmayo,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mbalmayo%2Ccm
# Retrieving weather information for inta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=inta%2Cru
# Retrieving weather information for puerto ayora,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=puerto+ayora%2Cec
# Retrieving weather information for jinxi,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jinxi%2Ccn
# Retrieving weather information for ikole,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ikole%2Cng
# Retrieving weather information for nogales,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nogales%2Cus
# Retrieving weather information for mubende,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mubende%2Cug
# Retrieving weather information for spornoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=spornoye%2Cru
# Retrieving weather information for poway,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=poway%2Cus
# Retrieving weather information for saint george,bm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=saint+george%2Cbm
# Retrieving weather information for eureka,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=eureka%2Cus
# Retrieving weather information for sukhumi,ge
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sukhumi%2Cge
# Retrieving weather information for peabiru,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=peabiru%2Cbr
# Retrieving weather information for kyrksaeterora,no
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kyrksaeterora%2Cno
# Retrieving weather information for jiangyin,cn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=jiangyin%2Ccn
# Retrieving weather information for clemson,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=clemson%2Cus
# Retrieving weather information for boguchany,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=boguchany%2Cru
# Retrieving weather information for edea,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=edea%2Ccm
# Retrieving weather information for nizhniy kuranakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nizhniy+kuranakh%2Cru
# Retrieving weather information for gornoye loo,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gornoye+loo%2Cru
# Retrieving weather information for anar darreh,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=anar+darreh%2Caf
# Retrieving weather information for tarhunah,ly
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tarhunah%2Cly
# Retrieving weather information for san carlos,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=san+carlos%2Cni
# Retrieving weather information for sisimiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=sisimiut%2Cgl
# Retrieving weather information for beamsville,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=beamsville%2Cca
# Retrieving weather information for south lake tahoe,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=south+lake+tahoe%2Cus
# Retrieving weather information for nova aurora,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nova+aurora%2Cbr
# Retrieving weather information for gladstone,au
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gladstone%2Cau
# Retrieving weather information for gossas,sn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gossas%2Csn
# Retrieving weather information for redlands,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=redlands%2Cus
# Retrieving weather information for limon,cr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=limon%2Ccr
# Retrieving weather information for el angel,ec
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=el+angel%2Cec
# Retrieving weather information for mwanza,mw
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=mwanza%2Cmw
# Retrieving weather information for haines junction,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=haines+junction%2Cca
# Retrieving weather information for skalistyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=skalistyy%2Cru
# Retrieving weather information for bafoussam,cm
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bafoussam%2Ccm
# Retrieving weather information for ligayan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ligayan%2Cph
# Retrieving weather information for cedar city,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=cedar+city%2Cus
# Retrieving weather information for athens,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=athens%2Cus
# Retrieving weather information for ancona,it
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ancona%2Cit
# Retrieving weather information for corinto,ni
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=corinto%2Cni
# Retrieving weather information for beruni,uz
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=beruni%2Cuz
# Retrieving weather information for los algarrobos,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=los+algarrobos%2Cpa
# Retrieving weather information for rancho palos verdes,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=rancho+palos+verdes%2Cus
# Retrieving weather information for monte aprazivel,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=monte+aprazivel%2Cbr
# Retrieving weather information for gazni,af
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=gazni%2Caf
# Retrieving weather information for chau doc,vn
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=chau+doc%2Cvn
# Retrieving weather information for oshawa,ca
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=oshawa%2Cca
# Retrieving weather information for voh,nc
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=voh%2Cnc
# Retrieving weather information for canandaigua,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=canandaigua%2Cus
# Retrieving weather information for ayolas,py
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=ayolas%2Cpy
# Retrieving weather information for malpe,in
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=malpe%2Cin
# Retrieving weather information for goderich,sl
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=goderich%2Csl
# Retrieving weather information for kotido,ug
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=kotido%2Cug
# Retrieving weather information for montalban,ph
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=montalban%2Cph
# Retrieving weather information for caceres,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=caceres%2Cbr
# Retrieving weather information for morgantown,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=morgantown%2Cus
# Retrieving weather information for joensuu,fi
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=joensuu%2Cfi
# Retrieving weather information for camopi,gf
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=camopi%2Cgf
# Retrieving weather information for bassila,bj
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bassila%2Cbj
# Retrieving weather information for florence,us
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=florence%2Cus
# Retrieving weather information for bauchi,ng
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=bauchi%2Cng
# Retrieving weather information for nobeoka,jp
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=nobeoka%2Cjp
# Retrieving weather information for akropong,gh
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=akropong%2Cgh
# Retrieving weather information for tommot,ru
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tommot%2Cru
# Retrieving weather information for eyrarbakki,is
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=eyrarbakki%2Cis
# Retrieving weather information for alegrete,br
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=alegrete%2Cbr
# Retrieving weather information for tarsus,tr
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=tarsus%2Ctr
# Retrieving weather information for morti,pa
# http://api.openweathermap.org/data/2.5/weather?appid=<YourKey>&units=metric&q=morti%2Cpa

# %%
# POST CALL-RETREIVING:  CLEAN UP DATA (When needed) AND EXPORT OUR DATA TO CSV:
selected_cities = selected_cities.dropna()

selected_cities.shape
selected_cities.to_csv("City_Weather_data_2.csv")

# %%
#  PLOTTING:  FIRST WE SET OUR PROPERTIES FOR OUR SCATTER-PLOTS:

# %%
# Plot settings
def set_plot_prop(x_title,x_lim,y_title):
    plt.title(f"{y_title} vs {x_title}")
    plt.ylabel(y_title)
    plt.xlabel(x_title)
    plt.grid(True)
    plt.xlim(x_lim)
